# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## 1. My Lane (or Freestyle) and Why

**Lane:** Refresh / Content Opportunity Scoring

I chose the Refresh / Content Opportunity Scoring lane because websites often contain thousands of pages, and reviewing every page is not practical. This project aims to identify which pages should be reviewed first based on their performance and content signals. The goal is to help content teams prioritize their work and make better decisions using data instead of guessing.
# Out:
#   File "/tmp/ipykernel_1946/1095068245.py", line 3
#     **Lane:** Refresh / Content Opportunity Scoring
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
## 2. The Question: Decision, Action, Cost of a Wrong Call

**Decision:** Decide which content pages should be reviewed first.

**Action:** A content or SEO team reviews the highest-ranked pages and updates them before lower-priority pages.

**Cost of a Wrong Call:** If a page is incorrectly marked as high priority, the team may waste time reviewing a page that does not need attention. If an important page is missed, a valuable opportunity to improve traffic or engagement may be delayed.
# Out:
#   File "/tmp/ipykernel_1946/1643377438.py", line 3
#     **Decision:** Decide which content pages should be reviewed first.
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df.head())

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## 4. Careful Words: What I Can and Can't Claim
#
# This project can identify patterns in the available data and provide decision-support recommendations for prioritizing content review. The results are based on observed signals and should be interpreted carefully.
#
# This project cannot prove that updating a page will improve rankings or traffic. It also cannot predict Google's algorithms or establish cause-and-effect relationships.

# %%
## 4. Careful Words: What I Can and Can't Claim

This project can identify patterns in the available data and provide decision-support recommendations for prioritizing content review. The results are based on observed signals and should be interpreted carefully.

This project cannot prove that updating a page will improve rankings or traffic. It also cannot predict Google's algorithms or establish cause-and-effect relationships.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
